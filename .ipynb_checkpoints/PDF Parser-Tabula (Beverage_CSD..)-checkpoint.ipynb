# %%
import tabula as tb

# %%
PDF_FILE = 'Beverage_CSD (GTC)_2DR - Narrow Short.pdf'

# %%
fc = 28.28
box = [2,8,20,28]
for i in range(0, len(box)):
    box[i] *= fc
print(box)
# Out:
# [56.56, 226.24, 565.6, 791.84]

# %%
import pdfplumber
import pandas as pd
required_column = ['LOC MCLANE', 'Desc_A', 'UNIT UPC', 'PACK', 'DESCRIPTION','Size', 'UOM', 'FACINGS']
final_df = []
with pdfplumber.open(PDF_FILE) as pdf:
        pages = pdf.pages
        for i,page in enumerate(pages):
            
            page_number = [i+1] 
            df = []
            if page_number[0]>2:
                print("Extracting Data from page:",page_number[0])
                tl = tb.read_pdf(PDF_FILE, pages=page_number,area=[box],output_format="dataframe", stream=True)
                df = tl[0]
                df = df[required_column]
                final_df.append(df)
                print(type(final_df))
                # df.drop(df.columns[[1]],axis=1, inplace=True)
#                 print(df)
final_df = pd.concat(final_df)
final_df = final_df[final_df[final_df.columns[0]].notna()] # Remove the rows where LOCMCLANE is NaN.
final_df.to_csv("demo.csv", index=False)
print(final_df)
# Out:
# Extracting Data from page: 3
# <class 'list'>
# Extracting Data from page: 4
# <class 'list'>
# Extracting Data from page: 5
# <class 'list'>
# Extracting Data from page: 6
# <class 'list'>
#    LOC MCLANE    Desc_A      UNIT UPC  PACK                    DESCRIPTION  \
# 0    DOOR 1/1       NaN           NaN   NaN                            NaN
# 1       1 DSD  124692.0  1.200015e+09  12.0  KICKSTART MIDNIGHT GRAPE 16OZ
# 2       2 DSD  110488.0  1.200004e+09  12.0        KICKSTART BLK CHRY 16OZ
# 3       3 DSD  103526.0  1.200011e+09  12.0      KICKSTART ORG CITRUS 16OZ
# 4       4 DSD  103525.0  1.200011e+09  12.0     KICKSTART FRUIT PUNCH 16OZ
# ..        ...       ...           ...   ...                            ...
# 21   DOOR NEW       NaN           NaN   NaN                            NaN
# 22      1 DSD  158426.0  1.200018e+09  24.0                    PEPSI MANGO
# 23      2 DSD  158427.0  1.200021e+09  24.0               PEPSI MANGO ZERO
# 24      3 DSD  159065.0  7.800004e+09  24.0                 DR PEPPER ZERO
# 25      4 DSD  151778.0  8.806706e+09  12.0                 1919 ROOT BEER
#
#     Size  UOM  FACINGS
# 0    NaN  NaN      NaN
# 1   16.0   OZ      1.0
# 2   16.0   OZ      1.0
# 3   16.0   OZ      2.0
# 4   16.0   OZ      1.0
# ..   ...  ...      ...
# 21   NaN  NaN      NaN
# 22  20.0   OZ      1.0
# 23  20.0   OZ      1.0
# 24  20.0   OZ      1.0
# 25  16.0   OZ      1.0
#
# [82 rows x 8 columns]

# %%
import re

final_df = final_df.fillna(method='ffill')

for i in range(len(final_df)):
    loc_mclane = final_df.iloc[i][final_df.columns[0]] #final_df[final_df.columns[0]].values[i] #
    loc_mclane_prev = ''
    if loc_mclane.isdecimal():
        loc_mclane_prev = final_df.iloc[i-1][final_df.columns[0]]
        loc_mclane_new = loc_mclane + ' ' + loc_mclane_prev
        final_df.loc[i,final_df.columns[0]] = loc_mclane_new
        final_df_1 = final_df.drop([final_df.index[i]])
        final_df_1 = final_df_1.loc[final_df_1['LOC MCLANE'].str.contains("DOOR|\d+", case=False)]

# %%
final_df.to_csv("demo1.csv", index=False)

# %%
final_df_1.to_csv("demo2.csv", index=False)

# %%
final_df_1
# Out:
#    LOC MCLANE    Desc_A      UNIT UPC  PACK                     DESCRIPTION  \
# 0    DOOR 1/1       NaN           NaN   NaN                             NaN
# 1       1 DSD  124692.0  1.200015e+09  12.0   KICKSTART MIDNIGHT GRAPE 16OZ
# 2       2 DSD  110488.0  1.200004e+09  12.0         KICKSTART BLK CHRY 16OZ
# 3       3 DSD  103526.0  1.200011e+09  12.0       KICKSTART ORG CITRUS 16OZ
# 4       4 DSD  103525.0  1.200011e+09  12.0      KICKSTART FRUIT PUNCH 16OZ
# ..        ...       ...           ...   ...                             ...
# 21   DOOR NEW  144476.0  7.800003e+09  24.0  CANADA DRY GINGER ALE LEMONADE
# 22      1 DSD  158426.0  1.200018e+09  24.0                     PEPSI MANGO
# 23      2 DSD  158427.0  1.200021e+09  24.0                PEPSI MANGO ZERO
# 24      3 DSD  159065.0  7.800004e+09  24.0                  DR PEPPER ZERO
# 25      4 DSD  151778.0  8.806706e+09  12.0                  1919 ROOT BEER
#
#     Size  UOM  FACINGS
# 0    NaN  NaN      NaN
# 1   16.0   OZ      1.0
# 2   16.0   OZ      1.0
# 3   16.0   OZ      2.0
# 4   16.0   OZ      1.0
# ..   ...  ...      ...
# 21  20.0   OZ      1.0
# 22  20.0   OZ      1.0
# 23  20.0   OZ      1.0
# 24  20.0   OZ      1.0
# 25  16.0   OZ      1.0
#
# [78 rows x 8 columns]

# %%
d1= final_df_1.loc[:, :final_df_1.columns[0]] 
d2 = final_df_1.loc[:, final_df_1.columns[1]:]
print(type(d2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
combined_column = []
for i in range(len(d1)):
    val = d1.iloc[i][d1.columns[0]]
    combined_column.append([val.split()[0],val.split()[-1]])
#     loc_column.append(val.split()[0])
#     mclane_column.append(val.split()[-1])
# combined_column = pd.DataFrame([loc_column,mclane_column],columns=['LOC','MCLANE'])
print(combined_column)
# Out:
# [['DOOR', '1/1'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['DSD', 'DSD'], ['5', 'DSD'], ['6', 'DSD'], ['DOOR', '1/2'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['5', 'DSD'], ['DOOR', '1/3'], ['1', 'DSD'], ['2', 'DSD'], ['DOOR', '1/4'], ['1', 'DSD'], ['DOOR', '1/5'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['5', 'DSD'], ['6', 'DSD'], ['DOOR', '1/6'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['DOOR', '2/1'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['5', 'DSD'], ['5', 'DSD'], ['DOOR', '2/2'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['3', 'DSD'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['5', 'DSD'], ['DOOR', '2/4'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['5', 'DSD'], ['DOOR', '2/5'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['5', 'DSD'], ['5', 'DSD'], ['7', 'DSD'], ['8', 'DSD'], ['DOOR', '2/6'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['5', 'DSD'], ['DOOR', 'DISCO'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD'], ['5', 'DSD'], ['DOOR', 'NEW'], ['1', 'DSD'], ['2', 'DSD'], ['3', 'DSD'], ['4', 'DSD']]

# %%
combined_column_df = pd.DataFrame(combined_column,columns=['LOC','MCLANE'])
# print(d2.index)

d2.reset_index(drop=True, inplace=True)
combined_column_df.reset_index(drop=True, inplace=True)
final_table = pd.concat([combined_column_df, d2], axis=1)

final_table.to_csv("demo4.csv", index=False)

# %%
final_table
# Out:
#      LOC MCLANE    Desc_A      UNIT UPC  PACK                     DESCRIPTION  \
# 0   DOOR    1/1       NaN           NaN   NaN                             NaN
# 1      1    DSD  124692.0  1.200015e+09  12.0   KICKSTART MIDNIGHT GRAPE 16OZ
# 2      2    DSD  110488.0  1.200004e+09  12.0         KICKSTART BLK CHRY 16OZ
# 3      3    DSD  103526.0  1.200011e+09  12.0       KICKSTART ORG CITRUS 16OZ
# 4      4    DSD  103525.0  1.200011e+09  12.0      KICKSTART FRUIT PUNCH 16OZ
# ..   ...    ...       ...           ...   ...                             ...
# 74  DOOR    NEW  144476.0  7.800003e+09  24.0  CANADA DRY GINGER ALE LEMONADE
# 75     1    DSD  158426.0  1.200018e+09  24.0                     PEPSI MANGO
# 76     2    DSD  158427.0  1.200021e+09  24.0                PEPSI MANGO ZERO
# 77     3    DSD  159065.0  7.800004e+09  24.0                  DR PEPPER ZERO
# 78     4    DSD  151778.0  8.806706e+09  12.0                  1919 ROOT BEER
#
#     Size  UOM  FACINGS
# 0    NaN  NaN      NaN
# 1   16.0   OZ      1.0
# 2   16.0   OZ      1.0
# 3   16.0   OZ      2.0
# 4   16.0   OZ      1.0
# ..   ...  ...      ...
# 74  20.0   OZ      1.0
# 75  20.0   OZ      1.0
# 76  20.0   OZ      1.0
# 77  20.0   OZ      1.0
# 78  16.0   OZ      1.0
#
# [79 rows x 9 columns]

# %%
final_df_1
# Out:
#    LOC MCLANE    Desc_A      UNIT UPC  PACK                     DESCRIPTION  \
# 0    DOOR 1/1       NaN           NaN   NaN                             NaN
# 1       1 DSD  124692.0  1.200015e+09  12.0   KICKSTART MIDNIGHT GRAPE 16OZ
# 2       2 DSD  110488.0  1.200004e+09  12.0         KICKSTART BLK CHRY 16OZ
# 3       3 DSD  103526.0  1.200011e+09  12.0       KICKSTART ORG CITRUS 16OZ
# 4       4 DSD  103525.0  1.200011e+09  12.0      KICKSTART FRUIT PUNCH 16OZ
# ..        ...       ...           ...   ...                             ...
# 21   DOOR NEW  144476.0  7.800003e+09  24.0  CANADA DRY GINGER ALE LEMONADE
# 22      1 DSD  158426.0  1.200018e+09  24.0                     PEPSI MANGO
# 23      2 DSD  158427.0  1.200021e+09  24.0                PEPSI MANGO ZERO
# 24      3 DSD  159065.0  7.800004e+09  24.0                  DR PEPPER ZERO
# 25      4 DSD  151778.0  8.806706e+09  12.0                  1919 ROOT BEER
#
#     Size  UOM  FACINGS
# 0    NaN  NaN      NaN
# 1   16.0   OZ      1.0
# 2   16.0   OZ      1.0
# 3   16.0   OZ      2.0
# 4   16.0   OZ      1.0
# ..   ...  ...      ...
# 21  20.0   OZ      1.0
# 22  20.0   OZ      1.0
# 23  20.0   OZ      1.0
# 24  20.0   OZ      1.0
# 25  16.0   OZ      1.0
#
# [78 rows x 8 columns]

# %%
for i in range(len(d1)):
    door = d1.iloc[i][d1.columns[0]]

# %%
final_df_1
# Out:
#    LOC MCLANE    Desc_A      UNIT UPC  PACK                     DESCRIPTION  \
# 0    DOOR 1/1       NaN           NaN   NaN                             NaN
# 1       1 DSD  124692.0  1.200015e+09  12.0   KICKSTART MIDNIGHT GRAPE 16OZ
# 2       2 DSD  110488.0  1.200004e+09  12.0         KICKSTART BLK CHRY 16OZ
# 3       3 DSD  103526.0  1.200011e+09  12.0       KICKSTART ORG CITRUS 16OZ
# 4       4 DSD  103525.0  1.200011e+09  12.0      KICKSTART FRUIT PUNCH 16OZ
# ..        ...       ...           ...   ...                             ...
# 21   DOOR NEW  144476.0  7.800003e+09  24.0  CANADA DRY GINGER ALE LEMONADE
# 22      1 DSD  158426.0  1.200018e+09  24.0                     PEPSI MANGO
# 23      2 DSD  158427.0  1.200021e+09  24.0                PEPSI MANGO ZERO
# 24      3 DSD  159065.0  7.800004e+09  24.0                  DR PEPPER ZERO
# 25      4 DSD  151778.0  8.806706e+09  12.0                  1919 ROOT BEER
#
#     Size  UOM  FACINGS
# 0    NaN  NaN      NaN
# 1   16.0   OZ      1.0
# 2   16.0   OZ      1.0
# 3   16.0   OZ      2.0
# 4   16.0   OZ      1.0
# ..   ...  ...      ...
# 21  20.0   OZ      1.0
# 22  20.0   OZ      1.0
# 23  20.0   OZ      1.0
# 24  20.0   OZ      1.0
# 25  16.0   OZ      1.0
#
# [78 rows x 8 columns]

# %%
import re
door_re = re.compile(r'DOOR')
door = []
door_num = ''
for i in range(len(final_df_1)):
#     x = final_df_1.loc[final_df_1['LOC MCLANE'].str.contains("DOOR", case=False)]
    x = final_df_1.iloc[i][final_df_1.columns[0]]
    if door_re.search(x):
        door_num = x.split()[1]
    
    door.append(door_num)
    
print(len(door))
# Out:
# 78

# %%
result = final_df_1.append(pd.DataFrame(door,columns=['Door']))

# %%
l1 = final_df.iloc[6]
print(type(l1))
# Out:
# <class 'pandas.core.series.Series'>

# %%
l2 = final_df.iloc[5]
l1
# Out:
# LOC MCLANE      5
# Desc_A          0
# UNIT UPC        0
# PACK            0
# DESCRIPTION     0
# Size           16
# UOM            OZ
# FACINGS         2
# Name: 6, dtype: object

# %%
l3 = str(l1)+str(l2)

# %%
l3_series = pd.Series(l3)
l3_series
# Out:
# 0    LOC MCLANE      5\nDesc_A          0\nUNIT UPC...
# dtype: object

# %% [raw]
# d1 = pd.DataFrame()
# d2 = pd.DataFrame()
# for i in float_list:
#     d1 = final_df[0:i]
#     d2 = final_df[i:]
#     print(i)
#
# # d1 = final_df[]
# # d1

# %%
d1
# Out:
#    LOC MCLANE    Desc_A      UNIT UPC  PACK                       DESCRIPTION  \
# 0    DOOR 1/1       NaN           NaN   NaN                               NaN
# 1       1 DSD  124692.0  1.200015e+09  12.0     KICKSTART MIDNIGHT GRAPE 16OZ
# 2       2 DSD  110488.0  1.200004e+09  12.0           KICKSTART BLK CHRY 16OZ
# 3       3 DSD  103526.0  1.200011e+09  12.0         KICKSTART ORG CITRUS 16OZ
# 4       4 DSD  103525.0  1.200011e+09  12.0        KICKSTART FRUIT PUNCH 16OZ
# 5         DSD  144493.0  1.200018e+09  12.0  KICKSTART PINEAPPLE ORANGE MANGO
# 6           5       NaN           NaN   NaN                               NaN
# 7         NaN       NaN           NaN   NaN                              16OZ
# 8       6 DSD   84204.0  1.200003e+09  24.0                   MT DEW CAN 16OZ
# 9    DOOR 1/2       NaN           NaN   NaN                               NaN
# 10      1 DSD  158427.0  1.200021e+09  24.0                  PEPSI MANGO ZERO
# 11      2 DSD  158426.0  1.200018e+09  24.0                       PEPSI MANGO
# 12        DSD  138606.0  1.200017e+09  24.0            PEPSI WLD CHRY DT 20OZ
# 13          3       NaN           NaN   NaN                               NaN
#
#     Size  UOM  FACINGS
# 0    NaN  NaN      NaN
# 1   16.0   OZ      1.0
# 2   16.0   OZ      1.0
# 3   16.0   OZ      2.0
# 4   16.0   OZ      1.0
# 5    NaN  NaN      NaN
# 6   16.0   OZ      2.0
# 7    NaN  NaN      NaN
# 8   16.0   OZ      2.0
# 9    NaN  NaN      NaN
# 10  20.0   OZ      1.0
# 11  20.0   OZ      1.0
# 12   NaN  NaN      NaN
# 13  20.0   OZ      1.0

# %%
d2
# Out:
#    LOC MCLANE    Desc_A      UNIT UPC  PACK          DESCRIPTION  Size  UOM  \
# 14        NaN       NaN           NaN   NaN                  NEW   NaN  NaN
# 15      4 DSD   20213.0  1.200001e+09  24.0  PEPSI WLD CHRY 20OZ  20.0   OZ
# 16      5 DSD   20229.0  1.200000e+09  24.0           PEPSI 20OZ  20.0   OZ
# 17   DOOR 1/3       NaN           NaN   NaN                  NaN   NaN  NaN
# 18      1 DSD   20214.0  1.200000e+09  24.0       MT DEW DT 20OZ  20.0   OZ
# ..        ...       ...           ...   ...                  ...   ...  ...
# 21   DOOR NEW       NaN           NaN   NaN                  NaN   NaN  NaN
# 22      1 DSD  158426.0  1.200018e+09  24.0          PEPSI MANGO  20.0   OZ
# 23      2 DSD  158427.0  1.200021e+09  24.0     PEPSI MANGO ZERO  20.0   OZ
# 24      3 DSD  159065.0  7.800004e+09  24.0       DR PEPPER ZERO  20.0   OZ
# 25      4 DSD  151778.0  8.806706e+09  12.0       1919 ROOT BEER  16.0   OZ
#
#     FACINGS
# 14      NaN
# 15      2.0
# 16      3.0
# 17      NaN
# 18      5.0
# ..      ...
# 21      NaN
# 22      1.0
# 23      1.0
# 24      1.0
# 25      1.0
#
# [70 rows x 8 columns]

# %%
d3 = final_df.head(7).combine_first(final_df.tail(7))

# %%
d3
# Out:
#    LOC MCLANE    Desc_A      UNIT UPC  PACK                       DESCRIPTION  \
# 0    DOOR 1/1       NaN           NaN   NaN                               NaN
# 1       1 DSD  124692.0  1.200015e+09  12.0     KICKSTART MIDNIGHT GRAPE 16OZ
# 2       2 DSD  110488.0  1.200004e+09  12.0           KICKSTART BLK CHRY 16OZ
# 3       3 DSD  103526.0  1.200011e+09  12.0         KICKSTART ORG CITRUS 16OZ
# 4       4 DSD  103525.0  1.200011e+09  12.0        KICKSTART FRUIT PUNCH 16OZ
# 5         DSD  144493.0  1.200018e+09  12.0  KICKSTART PINEAPPLE ORANGE MANGO
# 6           5       NaN           NaN   NaN                               NaN
# 19      4 DSD  144449.0  1.200018e+09  24.0                PEPSI VANILLA 20OZ
# 20      5 DSD  144476.0  7.800003e+09  24.0    CANADA DRY GINGER ALE LEMONADE
# 21   DOOR NEW       NaN           NaN   NaN                               NaN
# 22      1 DSD  158426.0  1.200018e+09  24.0                       PEPSI MANGO
# 23      2 DSD  158427.0  1.200021e+09  24.0                  PEPSI MANGO ZERO
# 24      3 DSD  159065.0  7.800004e+09  24.0                    DR PEPPER ZERO
# 25      4 DSD  151778.0  8.806706e+09  12.0                    1919 ROOT BEER
#
#     Size  UOM  FACINGS
# 0    NaN  NaN      NaN
# 1   16.0   OZ      1.0
# 2   16.0   OZ      1.0
# 3   16.0   OZ      2.0
# 4   16.0   OZ      1.0
# 5    NaN  NaN      NaN
# 6   16.0   OZ      2.0
# 19  20.0   OZ      1.0
# 20  20.0   OZ      1.0
# 21   NaN  NaN      NaN
# 22  20.0   OZ      1.0
# 23  20.0   OZ      1.0
# 24  20.0   OZ      1.0
# 25  16.0   OZ      1.0

# %%
d2 = final_df.tail(float_list[0])
d2
# Out:
#    LOC MCLANE    Desc_A      UNIT UPC  PACK                     DESCRIPTION  \
# 19      4 DSD  144449.0  1.200018e+09  24.0              PEPSI VANILLA 20OZ
# 20      5 DSD  144476.0  7.800003e+09  24.0  CANADA DRY GINGER ALE LEMONADE
# 21   DOOR NEW       NaN           NaN   NaN                             NaN
# 22      1 DSD  158426.0  1.200018e+09  24.0                     PEPSI MANGO
# 23      2 DSD  158427.0  1.200021e+09  24.0                PEPSI MANGO ZERO
# 24      3 DSD  159065.0  7.800004e+09  24.0                  DR PEPPER ZERO
# 25      4 DSD  151778.0  8.806706e+09  12.0                  1919 ROOT BEER
#
#     Size  UOM  FACINGS
# 19  20.0   OZ      1.0
# 20  20.0   OZ      1.0
# 21   NaN  NaN      NaN
# 22  20.0   OZ      1.0
# 23  20.0   OZ      1.0
# 24  20.0   OZ      1.0
# 25  16.0   OZ      1.0
